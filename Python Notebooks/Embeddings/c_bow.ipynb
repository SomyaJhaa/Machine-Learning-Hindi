# %% [markdown]
# CBOW ( Continuous Bag of Words )
# Applying this embedding method on the given hindi reviews dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
import string
import re
import pickle

from __future__ import print_function
from matplotlib import pylab
from matplotlib.font_manager import FontProperties
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# Giving the location of my dataset folder.

# %%
root = '/content/drive/MyDrive/Project 6th Sem'

# %% [markdown]
# Importing the Hindi font as it isn't comes inbuilt on python library.

# %%
hindiFont = FontProperties(fname=os.path.join(root, 'HindiFont.ttf'))

# %% [markdown]
# Cleaning dataset

# %%
# Making a function for cleaning the dataset
# This will take data to be cleaned as input along with the language on which I will clean
def clean_text(sentence, language):

    if language == None:
        print(" Language doesn't found : ")
        return None

    exclude = set(string.punctuation)
    remove_digits = str.maketrans('', '', string.digits)

    if language == 'english':
        sentence = sentence.lower()
        sentence = ''.join(ch for ch in sentence if ch not in exclude)
        sentence = sentence.translate(remove_digits)
        sentence = sentence.strip()
        sentence = re.sub(" +", " ", sentence)
        return sentence

    elif language == 'hindi':
        sentence = sentence.lower()
        sentence = ''.join(ch for ch in sentence if ch not in exclude)

        sent_temp = ''
        for c in sentence:
            if c == ' ':
                sent_temp += c
            elif ord(u'\u0900') <= ord(c) <= ord(u'\u097F'):
                sent_temp += c
        sentence = sent_temp

        sentence = re.sub('[a-z]', '', sentence)
        sentence = re.sub('[०१२३४५६७८९।]', '', sentence)
        sentence = sentence.translate(remove_digits)
        sentence = sentence.strip()
        sentence = re.sub(" +", " ", sentence)
        return sentence

    elif language == 'ma':
        sentence = sentence.lower()
        sentence = ''.join(ch for ch in sentence if ch not in exclude)
        sentence = re.sub('[a-z]', '', sentence)
        sentence = re.sub('[०१२३४५६७८९।]', '', sentence)
        sentence = sentence.translate(remove_digits)
        sentence = sentence.strip()
        sentence = re.sub(" +", " ", sentence)
        return sentence

    else:
        print("Language not found")
        return None

# %% [markdown]
# Reading the data from given dataset

# %%
# Making a function to directly call

def read_data(filename, number_of_lines):
    data = list()

    with open(os.path.join(root, filename)) as f:
        for i in  range(number_of_lines):
            data.extend(clean_text(tf.compat.as_str(f.readline()).strip(), 'hindi').split(' '))
    return data

# %%
# Reading data and storing it in variable 'sabd' ( as the hindi of word is sabd )
# As the dataset is large : it will take some time to process
sabd = read_data('Hindi_movies_review_train.csv', 5000000)
print("Data size is %d" % len(sabd))
# Out:
# Data size 5473242

# %% [markdown]
# Assuming a vocabulary size

# %%
vocabulary_size = int(len(set(sabd)) // 1.5)

# %% [markdown]
# Building the dataset

# %%
# UNK = Unknow

# %%
# Creating helper function to build dataset
# This will take input of readen data and return the dictionary etc useful items
def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
    dictionary = dict()

    for word, _ in count:
        dictionary[word] = len(dictionary)

    data = list()
    unk_count = 0

    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0
            unk_count += 1
        data.append(index)

    count[0][1] = unk_count

    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
# Building the dataset and storing the returned result
data, count, dictionary, reverse_dictionary = build_dataset(sabd)
print("Vocabulary size : ", vocabulary_size)
print("Most common words (inclusing UNK) : ", count[:5])
print("Sample data : ", data[:10])
del sabd
# Out:
# Vocabulary size :  13457
# Most common words (inclusing UNK) :  [['UNK', 6730], ('', 4989945), ('है', 26342), ('के', 15198), ('में', 12963)]
# Sample data :  [1, 2368, 186, 7848, 6, 582, 1245, 212, 179, 5]

# %% [markdown]
# Generating Batch ( This is what makes CBOW different from Skip gram )

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1
    batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)

    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
print('Data : ', [reverse_dictionary[di] for di in data[:6]])
# Out:
# Data :  ['', 'चंद्रमोहन', 'शर्मा', 'कोप्रड्यूसर', 'और', 'लीड']

# %%
# Generating different batches

# Taking the batch size = 4
batchSize = 4
for bag_window in [1, 2, 3]:
    data_index = 0
    batch, labels = generate_batch( batchSize, bag_window=bag_window)
    print("\nwith bag_window = %d:" % (bag_window))
    print(" batch:", [[reverse_dictionary[w] for w in bi] for bi in batch])
    print(" label:", [reverse_dictionary[li] for li in labels.reshape(batchSize)])
# Out:
# with bag_window = 1:
#  batch: [['', 'शर्मा'], ['चंद्रमोहन', 'कोप्रड्यूसर'], ['शर्मा', 'और'], ['कोप्रड्यूसर', 'लीड']]
#  label: ['चंद्रमोहन', 'शर्मा', 'कोप्रड्यूसर', 'और']
#
# with bag_window = 2:
#  batch: [['', 'चंद्रमोहन', 'कोप्रड्यूसर', 'और'], ['चंद्रमोहन', 'शर्मा', 'और', 'लीड'], ['शर्मा', 'कोप्रड्यूसर', 'लीड', 'ऐक्टर'], ['कोप्रड्यूसर', 'और', 'ऐक्टर', 'अक्षय']]
#  label: ['शर्मा', 'कोप्रड्यूसर', 'और', 'लीड']
#
# with bag_window = 3:
#  batch: [['', 'चंद्रमोहन', 'शर्मा', 'और', 'लीड', 'ऐक्टर'], ['चंद्रमोहन', 'शर्मा', 'कोप्रड्यूसर', 'लीड', 'ऐक्टर', 'अक्षय'], ['शर्मा', 'कोप्रड्यूसर', 'और', 'ऐक्टर', 'अक्षय', 'कुमार'], ['कोप्रड्यूसर', 'और', 'लीड', 'अक्षय', 'कुमार', 'की']]
#  label: ['कोप्रड्यूसर', 'और', 'लीड', 'ऐक्टर']

# %% [markdown]
# Tensorflow Graph

# %%
# To resolve the version issue
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
batch_size = 128
embedding_size = 128
bag_window = 2
valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,
                                                     inputs=tf.reduce_sum(embeds, 1), labels=train_labels,
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))

    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# Tooking nearest words \
# This will take some time to process as datatset is large

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    average_loss = 0

    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, bag_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l

        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            print("Average loss at step %d: %f" % (step, average_loss))
            average_loss = 0

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = "Nearest to %s:" % valid_word

                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = "%s %s" % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/tf_should_use.py:288: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.107762
# Nearest to कई: पड़ती वू भादुड़ी बेहोश स्कोर समानताएं विलन रेंसिल
# Nearest to पूरी: सुधारते गोलमाल बजते टूपीस सॉफ्ट वीं रिलायंस संपदा
# Nearest to ही: बैलेंस चलिए हवेली पप्पी पंप घायल भोजन अविवाहित
# Nearest to किरदार: जिंदा चिपका इलेक्ट्रिक घुमाने मैकक्वेरी शराब लड़कर ग्रैंडसन
# Nearest to खान: पुरु समन प्रोमो वंडर दीवाना मुंह अंदाज़ा सिंपल
# Nearest to बाद: गुंडा भागमभाग होमवर्क पैड्रो सरफिरा अपील छोड़कर कोंकणा
# Nearest to बहुत: सत्तर बाधक भविष्यवाणी डेस्टिनेशन शील्ड्स बैली गोलियाँ छूआ
# Nearest to उनकी: कुलकर्णी मुक्काबाज वाधवा सास कैस दौड़कर पेशे पियाली
# Nearest to में: खलते सुझाव कंसेप्ट इम्पॉसिबल संदीप डॉग पढ़ाते उसी
# Nearest to जो: टारजन सपनों चरित्रों नायर टुकड़ोंटुकड़ों जासूसी उन्हें वाडिया
# Nearest to की: उपस्थिति साइकोपैथ फ्यार अंताक्षरी दौड़ाना पुजारी अशुद्ध झुंझलाहट
# Nearest to दर्शकों: पौराणिक घेर विनोद औलाद राजीव तमाचा टपकने देखने
# Nearest to वाले: पोता गुलाब एविल ईमानदारी गोगी सुधीर लक्की द्वारा
# Nearest to लिए: जहां पेयर पॉजिटिव छाई हैंड बड़ी पूर्वजों दारोमदार
# Nearest to और: ट्रेवल छूते दारू डेविड अदाकार साराह मुस्कुराने समांतर
# Nearest to हैं: करवाई कपू खेतान उड़ान दहशत सम अनप्लग्ड नकाब
# Average loss at step 2000: 3.941606
# Average loss at step 4000: 2.784115
# Average loss at step 6000: 0.000001
# Average loss at step 8000: 0.000000
# Average loss at step 10000: 0.000000
# Nearest to कई: कुछ हर समानताएं सुन्हील पड़ती पहली सीटों दादाजी
# Nearest to पूरी: जिस वीं इस बड़ोदरा व्यवहार संपदा डॉक्टर्स बेवफाई
# Nearest to ही: सेरा चारा बैलेंस वॉर्स दर्शनीय बनाना मारू एकाएक
# Nearest to किरदार: रोल चौथा रोने किरदारों अभिनय मर्डर पॉवर बारे
# Nearest to खान: समन धुलाई रितेश सिंपल आर्ची जैसेजैसे हैप्पीसोनिया सीधें
# Nearest to बाद: लिए बावजूद साथ पहले अलावा इर्दगिर्द जरिये कारण
# Nearest to बहुत: यारो चैल बाधक कुलराज सिनेविजन दना करवाते सोचकर
# Nearest to उनकी: उसकी अपनी की बुलाती कुलकर्णी थापा बखान वार्तालाप
# Nearest to में: क्राय पर पैगाम बेसब्र सुदेश माजरा मंत्रियों प्रताड़ना
# Nearest to जो: लेकिन वह और टेक्निकल खरीदता नर्सों करप्ट कोफ्त
# Nearest to की: उसकी मंजर उनकी अपनी यूनिफॉर्म वाली अपनाने चाची
# Nearest to दर्शकों: देखने मोरिस धारावी मनोदशा पौराणिक सरसों मकबूल किताब
# Nearest to वाले: वाला वाली एविल पोता चार गुलाब गोगी सुधीर
# Nearest to लिए: बाद साथ जरिये खिलाफ पास बावजूद बीच साथसाथ
# Nearest to और: लेकिन तो कि करवाकर कितने जो सीधेसीधे जब
# Nearest to हैं: थे है हुए ऐलान दहशत कपू कहाँ सादा
# Average loss at step 12000: 0.000000
# Average loss at step 14000: 0.000000
# Average loss at step 16000: 0.000000
# Average loss at step 18000: 0.000000
# Average loss at step 20000: 0.000000
# Nearest to कई: कुछ हर समानताएं सुन्हील पड़ती पहली सीटों दादाजी
# Nearest to पूरी: जिस वीं इस बड़ोदरा व्यवहार संपदा डॉक्टर्स बेवफाई
# Nearest to ही: सेरा चारा बैलेंस वॉर्स दर्शनीय बनाना मारू एकाएक
# Nearest to किरदार: रोल चौथा रोने किरदारों अभिनय मर्डर पॉवर बारे
# Nearest to खान: समन धुलाई रितेश सिंपल आर्ची जैसेजैसे हैप्पीसोनिया सीधें
# Nearest to बाद: लिए बावजूद साथ पहले अलावा इर्दगिर्द जरिये कारण
# Nearest to बहुत: यारो चैल बाधक कुलराज सिनेविजन दना करवाते सोचकर
# Nearest to उनकी: उसकी अपनी की बुलाती कुलकर्णी थापा बखान वार्तालाप
# Nearest to में: क्राय पर पैगाम बेसब्र सुदेश माजरा मंत्रियों प्रताड़ना
# Nearest to जो: लेकिन वह और टेक्निकल खरीदता नर्सों करप्ट कोफ्त
# Nearest to की: उसकी मंजर उनकी अपनी यूनिफॉर्म वाली अपनाने चाची
# Nearest to दर्शकों: देखने मोरिस धारावी मनोदशा पौराणिक सरसों मकबूल किताब
# Nearest to वाले: वाला वाली एविल पोता चार गुलाब गोगी सुधीर
# Nearest to लिए: बाद साथ जरिये खिलाफ पास बावजूद बीच साथसाथ
# Nearest to और: लेकिन तो कि करवाकर कितने जो सीधेसीधे जब
# Nearest to हैं: थे है हुए ऐलान दहशत कपू कहाँ सादा
# Average loss at step 22000: 0.000000
# Average loss at step 24000: 0.000000
# Average loss at step 26000: 0.000000
# Average loss at step 28000: 0.000000
# Average loss at step 30000: 0.000000
# Nearest to कई: कुछ हर समानताएं सुन्हील पड़ती पहली सीटों दादाजी
# Nearest to पूरी: जिस वीं इस बड़ोदरा व्यवहार संपदा डॉक्टर्स बेवफाई
# Nearest to ही: सेरा चारा बैलेंस वॉर्स दर्शनीय बनाना मारू एकाएक
# Nearest to किरदार: रोल चौथा रोने किरदारों अभिनय मर्डर पॉवर बारे
# Nearest to खान: समन धुलाई रितेश सिंपल आर्ची जैसेजैसे हैप्पीसोनिया सीधें
# Nearest to बाद: लिए बावजूद साथ पहले अलावा इर्दगिर्द जरिये कारण
# Nearest to बहुत: यारो चैल बाधक कुलराज सिनेविजन दना करवाते सोचकर
# Nearest to उनकी: उसकी अपनी की बुलाती कुलकर्णी थापा बखान वार्तालाप
# Nearest to में: क्राय पर पैगाम बेसब्र सुदेश माजरा मंत्रियों प्रताड़ना
# Nearest to जो: लेकिन वह और टेक्निकल खरीदता नर्सों करप्ट कोफ्त
# Nearest to की: उसकी मंजर उनकी अपनी यूनिफॉर्म वाली अपनाने चाची
# Nearest to दर्शकों: देखने मोरिस धारावी मनोदशा पौराणिक सरसों मकबूल किताब
# Nearest to वाले: वाला वाली एविल पोता चार गुलाब गोगी सुधीर
# Nearest to लिए: बाद साथ जरिये खिलाफ पास बावजूद बीच साथसाथ
# Nearest to और: लेकिन तो कि करवाकर कितने जो सीधेसीधे जब
# Nearest to हैं: थे है हुए ऐलान दहशत कपू कहाँ सादा
# Average loss at step 32000: 0.000000
# Average loss at step 34000: 0.000000
# Average loss at step 36000: 0.000000
# Average loss at step 38000: 0.000000
# Average loss at step 40000: 0.000000
# Nearest to कई: कुछ हर समानताएं सुन्हील पड़ती पहली सीटों दादाजी
# Nearest to पूरी: जिस वीं इस बड़ोदरा व्यवहार संपदा डॉक्टर्स बेवफाई
# Nearest to ही: सेरा चारा बैलेंस वॉर्स दर्शनीय बनाना मारू एकाएक
# Nearest to किरदार: रोल चौथा रोने किरदारों अभिनय मर्डर पॉवर बारे
# Nearest to खान: समन धुलाई रितेश सिंपल आर्ची जैसेजैसे हैप्पीसोनिया सीधें
# Nearest to बाद: लिए बावजूद साथ पहले अलावा इर्दगिर्द जरिये कारण
# Nearest to बहुत: यारो चैल बाधक कुलराज सिनेविजन दना करवाते सोचकर
# Nearest to उनकी: उसकी अपनी की बुलाती कुलकर्णी थापा बखान वार्तालाप
# Nearest to में: क्राय पर पैगाम बेसब्र सुदेश माजरा मंत्रियों प्रताड़ना
# Nearest to जो: लेकिन वह और टेक्निकल खरीदता नर्सों करप्ट कोफ्त
# Nearest to की: उसकी मंजर उनकी अपनी यूनिफॉर्म वाली अपनाने चाची
# Nearest to दर्शकों: देखने मोरिस धारावी मनोदशा पौराणिक सरसों मकबूल किताब
# Nearest to वाले: वाला वाली एविल पोता चार गुलाब गोगी सुधीर
# Nearest to लिए: बाद साथ जरिये खिलाफ पास बावजूद बीच साथसाथ
# Nearest to और: लेकिन तो कि करवाकर कितने जो सीधेसीधे जब
# Nearest to हैं: थे है हुए ऐलान दहशत कपू कहाँ सादा
# Average loss at step 42000: 1.137694
# Average loss at step 44000: 2.656047
# Average loss at step 46000: 1.089517
# Average loss at step 48000: 0.000000
# Average loss at step 50000: 0.000000
# Nearest to कई: कुछ पहली हर एक सुन्हील सिक्यूरिटी दादाजी शूजित
# Nearest to पूरी: जिस इस किस किसी बड़ोदरा बिताने व्यवहार डॉक्टर्स
# Nearest to ही: भी सेरा बटोरी मुंहतोड़ बैलेंस कलेवर दर्शनीय चारा
# Nearest to किरदार: रोल किरदारों चौथा रोने पॉवर सफर बारे चढ़ाया
# Nearest to खान: धुलाई तरस हैप्पीसोनिया अय्यर रितेश जैसेजैसे आर्ची मंगल
# Nearest to बाद: लिए बावजूद पहले अलावा साथ पीछे कारण पिछले
# Nearest to बहुत: यारो दना चैल कैलाश लड़कालड़की एकमात्र हल्दीपुर बैली
# Nearest to उनकी: उसकी अपनी इनकी की बुलाती वार्तालाप बखान माइंडलेस
# Nearest to में: क्राय मंत्रियों पर तांगुं पैगाम अल्टर पारिवारिक सुदेश
# Nearest to जो: लेकिन रूटीन वो कोफ्त वह खरीदता और टेक्निकल
# Nearest to की: मंजर उनकी उसकी वाली अपनी सुपुर्द बुरी प्लाट
# Nearest to दर्शकों: दर्शक रियलिटी देखने लोगों धारावी राजनेता सरसों उधर
# Nearest to वाले: वाला वाली वालों एविल पोता चार मिंटू सुधीर
# Nearest to लिए: बाद जरिये साथ खिलाफ साथसाथ पास अलावा बावजूद
# Nearest to और: लेकिन कि जैसे तो जो अटकाता कितने थकाऊ
# Nearest to हैं: थे है हुए ऐलान कपू थी फिल्म् गूंथ
# Average loss at step 52000: 0.000000
# Average loss at step 54000: 0.000000
# Average loss at step 56000: 0.000000
# Average loss at step 58000: 0.000000
# Average loss at step 60000: 0.000000
# Nearest to कई: कुछ पहली हर एक सुन्हील सिक्यूरिटी दादाजी शूजित
# Nearest to पूरी: जिस इस किस किसी बड़ोदरा बिताने व्यवहार डॉक्टर्स
# Nearest to ही: भी सेरा बटोरी मुंहतोड़ बैलेंस कलेवर दर्शनीय चारा
# Nearest to किरदार: रोल किरदारों चौथा रोने पॉवर सफर बारे चढ़ाया
# Nearest to खान: धुलाई तरस हैप्पीसोनिया अय्यर रितेश जैसेजैसे आर्ची मंगल
# Nearest to बाद: लिए बावजूद पहले अलावा साथ पीछे कारण पिछले
# Nearest to बहुत: यारो दना चैल कैलाश लड़कालड़की एकमात्र हल्दीपुर बैली
# Nearest to उनकी: उसकी अपनी इनकी की बुलाती वार्तालाप बखान माइंडलेस
# Nearest to में: क्राय मंत्रियों पर तांगुं पैगाम अल्टर पारिवारिक सुदेश
# Nearest to जो: लेकिन रूटीन वो कोफ्त वह खरीदता और टेक्निकल
# Nearest to की: मंजर उनकी उसकी वाली अपनी सुपुर्द बुरी प्लाट
# Nearest to दर्शकों: दर्शक रियलिटी देखने लोगों धारावी राजनेता सरसों उधर
# Nearest to वाले: वाला वाली वालों एविल पोता चार मिंटू सुधीर
# Nearest to लिए: बाद जरिये साथ खिलाफ साथसाथ पास अलावा बावजूद
# Nearest to और: लेकिन कि जैसे तो जो अटकाता कितने थकाऊ
# Nearest to हैं: थे है हुए ऐलान कपू थी फिल्म् गूंथ
# Average loss at step 62000: 0.000000
# Average loss at step 64000: 0.000000
# Average loss at step 66000: 0.000000
# Average loss at step 68000: 0.000000
# Average loss at step 70000: 0.000000
# Nearest to कई: कुछ पहली हर एक सुन्हील सिक्यूरिटी दादाजी शूजित
# Nearest to पूरी: जिस इस किस किसी बड़ोदरा बिताने व्यवहार डॉक्टर्स
# Nearest to ही: भी सेरा बटोरी मुंहतोड़ बैलेंस कलेवर दर्शनीय चारा
# Nearest to किरदार: रोल किरदारों चौथा रोने पॉवर सफर बारे चढ़ाया
# Nearest to खान: धुलाई तरस हैप्पीसोनिया अय्यर रितेश जैसेजैसे आर्ची मंगल
# Nearest to बाद: लिए बावजूद पहले अलावा साथ पीछे कारण पिछले
# Nearest to बहुत: यारो दना चैल कैलाश लड़कालड़की एकमात्र हल्दीपुर बैली
# Nearest to उनकी: उसकी अपनी इनकी की बुलाती वार्तालाप बखान माइंडलेस
# Nearest to में: क्राय मंत्रियों पर तांगुं पैगाम अल्टर पारिवारिक सुदेश
# Nearest to जो: लेकिन रूटीन वो कोफ्त वह खरीदता और टेक्निकल
# Nearest to की: मंजर उनकी उसकी वाली अपनी सुपुर्द बुरी प्लाट
# Nearest to दर्शकों: दर्शक रियलिटी देखने लोगों धारावी राजनेता सरसों उधर
# Nearest to वाले: वाला वाली वालों एविल पोता चार मिंटू सुधीर
# Nearest to लिए: बाद जरिये साथ खिलाफ साथसाथ पास अलावा बावजूद
# Nearest to और: लेकिन कि जैसे तो जो अटकाता कितने थकाऊ
# Nearest to हैं: थे है हुए ऐलान कपू थी फिल्म् गूंथ
# Average loss at step 72000: 0.000000
# Average loss at step 74000: 0.000000
# Average loss at step 76000: 0.000000
# Average loss at step 78000: 0.000000
# Average loss at step 80000: 0.000000
# Nearest to कई: कुछ पहली हर एक सुन्हील सिक्यूरिटी दादाजी शूजित
# Nearest to पूरी: जिस इस किस किसी बड़ोदरा बिताने व्यवहार डॉक्टर्स
# Nearest to ही: भी सेरा बटोरी मुंहतोड़ बैलेंस कलेवर दर्शनीय चारा
# Nearest to किरदार: रोल किरदारों चौथा रोने पॉवर सफर बारे चढ़ाया
# Nearest to खान: धुलाई तरस हैप्पीसोनिया अय्यर रितेश जैसेजैसे आर्ची मंगल
# Nearest to बाद: लिए बावजूद पहले अलावा साथ पीछे कारण पिछले
# Nearest to बहुत: यारो दना चैल कैलाश लड़कालड़की एकमात्र हल्दीपुर बैली
# Nearest to उनकी: उसकी अपनी इनकी की बुलाती वार्तालाप बखान माइंडलेस
# Nearest to में: क्राय मंत्रियों पर तांगुं पैगाम अल्टर पारिवारिक सुदेश
# Nearest to जो: लेकिन रूटीन वो कोफ्त वह खरीदता और टेक्निकल
# Nearest to की: मंजर उनकी उसकी वाली अपनी सुपुर्द बुरी प्लाट
# Nearest to दर्शकों: दर्शक रियलिटी देखने लोगों धारावी राजनेता सरसों उधर
# Nearest to वाले: वाला वाली वालों एविल पोता चार मिंटू सुधीर
# Nearest to लिए: बाद जरिये साथ खिलाफ साथसाथ पास अलावा बावजूद
# Nearest to और: लेकिन कि जैसे तो जो अटकाता कितने थकाऊ
# Nearest to हैं: थे है हुए ऐलान कपू थी फिल्म् गूंथ
# Average loss at step 82000: 0.000000
# Average loss at step 84000: 1.984177
# Average loss at step 86000: 2.280363
# Average loss at step 88000: 0.000000
# Average loss at step 90000: 0.000000
# Nearest to कई: कुछ हर सुन्हील अँधेरा पहली सारे ज्यादातर एक
# Nearest to पूरी: जिस किस इस छुड़ाना किसी बड़ोदरा बिताने बुरी
# Nearest to ही: सेरा वॉर्स कलेवर बैलेंस एकाएक बटोरी दर्शनीय अंतर
# Nearest to किरदार: रोल किरदारों सफर चौथा पॉवर पेयर हिस्सा अंदाज
# Nearest to खान: अय्यर हैप्पीसोनिया मंगल धुलाई रितेश तरस जैसेजैसे नही
# Nearest to बाद: बावजूद लिए पहले अलावा पीछे कारण साथ पिछले
# Nearest to बहुत: बेहद भले सबब एकमात्र यू इतनी कैलाश काउंसिल
# Nearest to उनकी: उसकी इनकी अपनी बुलाती की वार्तालाप माइंडलेस गोगो
# Nearest to में: क्राय मंत्रियों अल्टर तांगुं बेसब्र पारिवारिक फरेब पैगाम
# Nearest to जो: लेकिन जिससे रूटीन वो खरीदता कोफ्त टेक्निकल हँसाना
# Nearest to की: उसकी मंजर उनकी वाली चाची अपनी बुरी दौड़ाना
# Nearest to दर्शकों: दर्शक रियलिटी लोगों संदेहास्पद सरसों धारावी देखने किताब
# Nearest to वाले: वाला वाली वालों कोठा चार कड़क पोता एविल
# Nearest to लिए: जरिये खिलाफ बाद अलावा पास साथ साथसाथ बावजूद
# Nearest to और: लेकिन अटकाता कि क्योंकि थकाऊ तो या ईजाद
# Nearest to हैं: थे है कपू हुए हों ऐलान फिल्म् थी
# Average loss at step 92000: 0.000000
# Average loss at step 94000: 0.000000
# Average loss at step 96000: 0.000000
# Average loss at step 98000: 0.000000
# Average loss at step 100000: 0.000000
# Nearest to कई: कुछ हर सुन्हील अँधेरा पहली सारे ज्यादातर एक
# Nearest to पूरी: जिस किस इस छुड़ाना किसी बड़ोदरा बिताने बुरी
# Nearest to ही: सेरा वॉर्स कलेवर बैलेंस एकाएक बटोरी दर्शनीय अंतर
# Nearest to किरदार: रोल किरदारों सफर चौथा पॉवर पेयर हिस्सा अंदाज
# Nearest to खान: अय्यर हैप्पीसोनिया मंगल धुलाई रितेश तरस जैसेजैसे नही
# Nearest to बाद: बावजूद लिए पहले अलावा पीछे कारण साथ पिछले
# Nearest to बहुत: बेहद भले सबब एकमात्र यू इतनी कैलाश काउंसिल
# Nearest to उनकी: उसकी इनकी अपनी बुलाती की वार्तालाप माइंडलेस गोगो
# Nearest to में: क्राय मंत्रियों अल्टर तांगुं बेसब्र पारिवारिक फरेब पैगाम
# Nearest to जो: लेकिन जिससे रूटीन वो खरीदता कोफ्त टेक्निकल हँसाना
# Nearest to की: उसकी मंजर उनकी वाली चाची अपनी बुरी दौड़ाना
# Nearest to दर्शकों: दर्शक रियलिटी लोगों संदेहास्पद सरसों धारावी देखने किताब
# Nearest to वाले: वाला वाली वालों कोठा चार कड़क पोता एविल
# Nearest to लिए: जरिये खिलाफ बाद अलावा पास साथ साथसाथ बावजूद
# Nearest to और: लेकिन अटकाता कि क्योंकि थकाऊ तो या ईजाद
# Nearest to हैं: थे है कपू हुए हों ऐलान फिल्म् थी

# %% [markdown]
# Output Visualisation

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=3, init='pca', n_iter=5000, method='exact') # I have taken n_components = 3 but it's giving same resukt as of 2 dimension
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))
    for i, label in enumerate(labels):
        x, y, z = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom', fontproperties=hindiFont)
    pylab.show()

# %%
sabd = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, sabd)

# %%
# To save the work
"""
final_data = {
    'embeddings': final_embeddings,
    'dictionary': dictionary,
    'reverse_dictionary': reverse_dictionary
}

with open(os.path.join(root, 'embeddings_cbow.hi'), 'wb') as f:
    pickle.dump(file=f, obj=final_data)
"""
# Out:
# "\nfinal_data = {\n    'embeddings': final_embeddings,\n    'dictionary': dictionary,\n    'reverse_dictionary': reverse_dictionary\n}\n\nwith open(os.path.join(root, 'embeddings_cbow.hi'), 'wb') as f:\n    pickle.dump(file=f, obj=final_data)\n"

# %%
# To view the saved embeddings
"""
import pickle

with open('/content/drive/MyDrive/Project/embeddings_cbow.hi', 'rb') as f:
    summary = pickle.load(f)

print(summary['embeddings'].shape)
print(summary['dictionary'].keys())
print(summary['reverse_dictionary'].keys())
"""
# Out:
# "\nimport pickle\n\nwith open('/content/drive/MyDrive/Project/embeddings_cbow.hi', 'rb') as f:\n    summary = pickle.load(f)\n\nprint(summary['embeddings'].shape)\nprint(summary['dictionary'].keys())\nprint(summary['reverse_dictionary'].keys())\n"
